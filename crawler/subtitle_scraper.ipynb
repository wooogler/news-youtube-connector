# %%
import requests
import json
api_key="AIzaSyDSXtTKauLEyewc8YtOOScZE3ycmKTNCUg"
channel_id = "UCqnbDFdCpuN8CMEg0VuEBqA"

# %%
res_channel = requests.get('https://www.googleapis.com/youtube/v3/channels?id={}&key={}&part=contentDetails'.format(channel_id, api_key))
uploads = res_channel.json()['items'][0]['contentDetails']['relatedPlaylists']['uploads']
video_ids = []
pageToken=''
for i in range(5):
  res_videos = requests.get('https://www.googleapis.com/youtube/v3/playlistItems?playlistId={}&key={}&part=snippet&pageToken={}&maxResults=50'.format(uploads, api_key, pageToken))
  res_videos_json = res_videos.json()
  video_ids = video_ids + [video['snippet']['resourceId']['videoId'] for video in res_videos_json['items']]
  pageToken = res_videos_json['nextPageToken']
video_ids
# Out:
# ['n54Jyt_P0FY',
#  'AoFdE0ssDSA',
#  'H8zDt4VKkVY',
#  'YAblAQENQhE',
#  'Jh3jTA4exGc',
#  '0fIbd4uq_5k',
#  '8BtPV1gIaJs',
#  'ifhD-ZGChr8',
#  'C1kTEit6-qw',
#  'gCS9Nlkq5ng',
#  '7xml90IvQJ0',
#  'Stl8wHlzN34',
#  'MpeX6Y9lOkM',
#  'm6xE7rieXU0',
#  'GkSsC6aCFbU',
#  'riC2lYr5pjo',
#  'l5ev_itkCB0',
#  'K4II9cYrQvE',
#  '4g7IOJygfr0',
#  'F7VJPgqYsBE',
#  'QS7kUqKeg_0',
#  'DXCd5810lTg',
#  'kOcLyyVyb6o',
#  '0ilKQRXySg8',
#  '6g2iyWeYm44',
#  'PrDyii0P4DU',
#  'mX5ObMEVurM',
#  'zyA68Gs1Mto',
#  'uQgHoWAU1go',
#  '4oDywexZT9U',
#  'ovahGit20vk',
#  'd6G3QNPQy80',
#  'S-T4-g_x4NA',
#  'hNRAjpmIhvk',
#  'jdMWNk-yFk4',
#  'cf_0bu_1Esc',
#  'hNDgcjVGHIw',
#  'LMGfaa_OMX4',
#  'VpTW2AJE9MQ',
#  '2axbxYbWLmk',
#  'yMCmlTkzlhM',
#  'YKkiNTE1b6w',
#  'iXKZtAiOPQE',
#  'nRFVR_JpxDc',
#  'BgtmWRJ_oUg',
#  'aK_ALMA1NMk',
#  'Z5wngMijElY',
#  'FgKkrdDgn5w',
#  'q0hqnMUi3NA',
#  'w8l4iI40ues',
#  'i-38KUU274c',
#  'je803DmNHn4',
#  'c8XD7tNstfw',
#  'TgGWi6xXVm8',
#  'G5KY-zChEEI',
# ...

# %%
from youtube_transcript_api import YouTubeTranscriptApi
import pandas as pd

for video_id in video_ids:
  try:
    df = pd.DataFrame(YouTubeTranscriptApi.get_transcript(video_id))
  except:
    continue
  df['text'] = df['text'].str.replace('\n',' ')
  df.to_csv('crawler/data/{}.csv'.format(video_id), index=False)
